# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

# %matplotlib inline
pd.set_option("display.max_rows", None,"display.max_columns", None)
warnings.simplefilter(action='ignore')
plt.style.use('seaborn')

# %%
#load dataset
df_main = pd.read_csv('car data.csv')

# %%
df_main.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df_main.shape
# Out:
# (301, 9)

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
#numerical stats
df_main.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
#missing values
df_main.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# Data Preprocessing

# %%
df_main['Age'] = 2020 - df_main['Year']
df_main.drop('Year',axis=1,inplace = True)

# %%
df_main.rename(columns = {'Selling_Price':'Selling_Price(lacs)','Present_Price':'Present_Price(lacs)','Owner':'Past_Owners'},inplace = True)

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
df_main.columns
# Out:
# Index(['Car_Name', 'Selling_Price(lacs)', 'Present_Price(lacs)', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Past_Owners', 'Age'],
#       dtype='object')

# %%
cat_cols = ['Fuel_Type','Seller_Type','Transmission','Past_Owners']
i=0
while i < 4:
    fig = plt.figure(figsize=[10,4])
    #ax1 = fig.add_subplot(121)
    #ax2 = fig.add_subplot(122)

    #ax1.title.set_text(cat_cols[i])
    plt.subplot(1,2,1)
    sns.countplot(x=cat_cols[i], data=df_main)
    i += 1

    #ax2.title.set_text(cat_cols[i])
    plt.subplot(1,2,2)
    sns.countplot(x=cat_cols[i], data=df_main)
    i += 1

    plt.show()

# %%
num_cols = ['Selling_Price(lacs)','Present_Price(lacs)','Kms_Driven','Age']
i=0
while i < 4:
    fig = plt.figure(figsize=[13,3])
    #ax1 = fig.add_subplot(121)
    #ax2 = fig.add_subplot(122)

    #ax1.title.set_text(num_cols[i])
    plt.subplot(1,2,1)
    sns.boxplot(x=num_cols[i], data=df_main)
    i += 1

    #ax2.title.set_text(num_cols[i])
    plt.subplot(1,2,2)
    sns.boxplot(x=num_cols[i], data=df_main)
    i += 1

    plt.show()

# %%
df_main[df_main['Present_Price(lacs)'] > df_main['Present_Price(lacs)'].quantile(0.99)]
# Out:
#         Car_Name  Selling_Price(lacs)  Present_Price(lacs)  Kms_Driven  \
# 64      fortuner                 33.0                36.23        6000
# 86  land cruiser                 35.0                92.60       78000
#
#    Fuel_Type Seller_Type Transmission  Past_Owners  Age
# 64    Diesel      Dealer    Automatic            0    3
# 86    Diesel      Dealer       Manual            0   10

# %%
df_main[df_main['Selling_Price(lacs)'] > df_main['Selling_Price(lacs)'].quantile(0.99)]
# Out:
#         Car_Name  Selling_Price(lacs)  Present_Price(lacs)  Kms_Driven  \
# 63      fortuner                 23.5                35.96       47000
# 64      fortuner                 33.0                36.23        6000
# 86  land cruiser                 35.0                92.60       78000
#
#    Fuel_Type Seller_Type Transmission  Past_Owners  Age
# 63    Diesel      Dealer    Automatic            0    5
# 64    Diesel      Dealer    Automatic            0    3
# 86    Diesel      Dealer       Manual            0   10

# %%
df_main[df_main['Kms_Driven'] > df_main['Kms_Driven'].quantile(0.99)]
# Out:
#           Car_Name  Selling_Price(lacs)  Present_Price(lacs)  Kms_Driven  \
# 84          innova                 3.49                13.46      197176
# 179  Honda Karizma                 0.31                 1.05      213000
# 196      Activa 3g                 0.17                 0.52      500000
#
#     Fuel_Type Seller_Type Transmission  Past_Owners  Age
# 84     Diesel      Dealer       Manual            0   15
# 179    Petrol  Individual       Manual            0   10
# 196    Petrol  Individual    Automatic            0   12

# %%
#Bivariate/Multi-Variate Analysis
# Exclude non-numeric columns from correlation calculation
sns.heatmap(df_main.select_dtypes(include=np.number).corr(), annot=True, cmap="RdBu")
plt.show()

# %%
# Convert the 'Seller_Type' column to a categorical data type
df_main['Seller_Type'] = df_main['Seller_Type'].astype('category')

# Calculate the correlation matrix
correlation_matrix = df_main.select_dtypes(include=np.number).corr()

# Access the correlation values for 'Selling_Price(lacs)'
correlation_with_selling_price = correlation_matrix['Selling_Price(lacs)']

print(correlation_with_selling_price)
# Out:
# Selling_Price(lacs)    1.000000
# Present_Price(lacs)    0.878983
# Kms_Driven             0.029187
# Past_Owners           -0.088344
# Age                   -0.236141
# Name: Selling_Price(lacs), dtype: float64

# %%
df_main.pivot_table(index='Seller_Type',values='Selling_Price(lacs)',aggfunc='mean')
 #Check for typos in this line and ensure that the 'Fuel_Type column exists. You can use df_main.columns to list all columns
# Out:
#              Selling_Price(lacs)
# Seller_Type
# Dealer                  6.721692
# Individual              0.870943

# %%
df_main.pivot_table(values='Selling_Price(lacs)', index = 'Seller_Type', columns= 'Transmission')
# Out:
# Transmission  Automatic    Manual
# Seller_Type
# Dealer        12.246552  5.756506
# Individual     1.968182  0.743895

# %% [markdown]
# Data Preparation
# Data Preparation

# %%
# Check if 'Car_Name' column exists before dropping
if 'Car_Name' in df_main.columns:
  df_main.drop('Car_Name',axis=1,inplace = True)

# %%
df_main.head()
# Out:
#    Selling_Price(lacs)  Present_Price(lacs)  Kms_Driven Seller_Type  \
# 0                 3.35                 5.59       27000      Dealer
# 1                 4.75                 9.54       43000      Dealer
# 2                 7.25                 9.85        6900      Dealer
# 3                 2.85                 4.15        5200      Dealer
# 4                 4.60                 6.87       42450      Dealer
#
#   Transmission  Past_Owners  Age  Car_Name_800  Car_Name_Activa 3g  \
# 0       Manual            0    6         False               False
# 1       Manual            0    7         False               False
# 2       Manual            0    3         False               False
# 3       Manual            0    9         False               False
# 4       Manual            0    6         False               False
#
#    Car_Name_Activa 4g  Car_Name_Bajaj  ct 100  Car_Name_Bajaj Avenger 150  \
# 0               False                   False                       False
# 1               False                   False                       False
# 2               False                   False                       False
# 3               False                   False                       False
# 4               False                   False                       False
#
#    Car_Name_Bajaj Avenger 150 street  Car_Name_Bajaj Avenger 220  \
# 0                              False                       False
# 1                              False                       False
# 2                              False                       False
# 3                              False                       False
# 4                              False                       False
#
#    Car_Name_Bajaj Avenger 220 dtsi  Car_Name_Bajaj Avenger Street 220  \
# 0                            False                              False
# 1                            False                              False
# 2                            False                              False
# 3                            False                              False
# 4                            False                              False
#
#    Car_Name_Bajaj Discover 100  Car_Name_Bajaj Discover 125  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    Car_Name_Bajaj Dominar 400  Car_Name_Bajaj Pulsar  NS 200  \
# 0                       False                          False
# 1                       False                          False
# 2                       False                          False
# 3                       False                          False
# 4                       False                          False
#
#    Car_Name_Bajaj Pulsar 135 LS  Car_Name_Bajaj Pulsar 150  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
#
#    Car_Name_Bajaj Pulsar 220 F  Car_Name_Bajaj Pulsar NS 200  \
# 0                        False                         False
# 1                        False                         False
# 2                        False                         False
# 3                        False                         False
# 4                        False                         False
#
#    Car_Name_Bajaj Pulsar RS200  Car_Name_Hero  CBZ Xtreme  \
# 0                        False                      False
# 1                        False                      False
# 2                        False                      False
# 3                        False                      False
# 4                        False                      False
#
#    Car_Name_Hero  Ignitor Disc  Car_Name_Hero Extreme  Car_Name_Hero Glamour  \
# 0                        False                  False                  False
# 1                        False                  False                  False
# 2                        False                  False                  False
# 3                        False                  False                  False
# 4                        False                  False                  False
#
#    Car_Name_Hero Honda CBZ extreme  Car_Name_Hero Honda Passion Pro  \
# 0                            False                            False
# 1                            False                            False
# 2                            False                            False
# 3                            False                            False
# 4                            False                            False
#
#    Car_Name_Hero Hunk  Car_Name_Hero Passion Pro  Car_Name_Hero Passion X pro  \
# 0               False                      False                        False
# 1               False                      False                        False
# 2               False                      False                        False
# 3               False                      False                        False
# 4               False                      False                        False
#
#    Car_Name_Hero Splender Plus  Car_Name_Hero Splender iSmart  \
# 0                        False                          False
# 1                        False                          False
# 2                        False                          False
# 3                        False                          False
# 4                        False                          False
#
#    Car_Name_Hero Super Splendor  Car_Name_Honda Activa 125  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
#
#    Car_Name_Honda Activa 4G  Car_Name_Honda CB Hornet 160R  \
# 0                     False                          False
# 1                     False                          False
# 2                     False                          False
# 3                     False                          False
# 4                     False                          False
#
#    Car_Name_Honda CB Shine  Car_Name_Honda CB Trigger  \
# 0                    False                      False
# 1                    False                      False
# 2                    False                      False
# 3                    False                      False
# 4                    False                      False
#
#    Car_Name_Honda CB Unicorn  Car_Name_Honda CB twister  \
# 0                      False                      False
# 1                      False                      False
# 2                      False                      False
# 3                      False                      False
# 4                      False                      False
#
#    Car_Name_Honda CBR 150  Car_Name_Honda Dream Yuga   Car_Name_Honda Karizma  \
# 0                   False                       False                   False
# 1                   False                       False                   False
# 2                   False                       False                   False
# 3                   False                       False                   False
# 4                   False                       False                   False
#
#    Car_Name_Hyosung GT250R  Car_Name_KTM 390 Duke   Car_Name_KTM RC200  \
# 0                    False                   False               False
# 1                    False                   False               False
# 2                    False                   False               False
# 3                    False                   False               False
# 4                    False                   False               False
#
#    Car_Name_KTM RC390  Car_Name_Mahindra Mojo XT300  \
# 0               False                         False
# 1               False                         False
# 2               False                         False
# 3               False                         False
# 4               False                         False
#
#    Car_Name_Royal Enfield Bullet 350  Car_Name_Royal Enfield Classic 350  \
# 0                              False                               False
# 1                              False                               False
# 2                              False                               False
# 3                              False                               False
# 4                              False                               False
#
#    Car_Name_Royal Enfield Classic 500  Car_Name_Royal Enfield Thunder 350  \
# 0                               False                               False
# 1                               False                               False
# 2                               False                               False
# 3                               False                               False
# 4                               False                               False
#
#    Car_Name_Royal Enfield Thunder 500  Car_Name_Suzuki Access 125  \
# 0                               False                       False
# 1                               False                       False
# 2                               False                       False
# 3                               False                       False
# 4                               False                       False
#
#    Car_Name_TVS Apache RTR 160  Car_Name_TVS Apache RTR 180  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    Car_Name_TVS Jupyter  Car_Name_TVS Sport   Car_Name_TVS Wego  \
# 0                 False                False              False
# 1                 False                False              False
# 2                 False                False              False
# 3                 False                False              False
# 4                 False                False              False
#
#    Car_Name_UM Renegade Mojave  Car_Name_Yamaha FZ  v 2.0  \
# 0                        False                      False
# 1                        False                      False
# 2                        False                      False
# 3                        False                      False
# 4                        False                      False
#
#    Car_Name_Yamaha FZ 16  Car_Name_Yamaha FZ S   Car_Name_Yamaha FZ S V 2.0  \
# 0                  False                  False                       False
# 1                  False                  False                       False
# 2                  False                  False                       False
# 3                  False                  False                       False
# 4                  False                  False                       False
#
#    Car_Name_Yamaha Fazer   Car_Name_alto 800  Car_Name_alto k10  \
# 0                   False              False              False
# 1                   False              False              False
# 2                   False              False              False
# 3                   False              False              False
# 4                   False              False              False
#
#    Car_Name_amaze  Car_Name_baleno  Car_Name_brio  Car_Name_camry  \
# 0           False            False          False           False
# 1           False            False          False           False
# 2           False            False          False           False
# 3           False            False          False           False
# 4           False            False          False           False
#
#    Car_Name_ciaz  Car_Name_city  Car_Name_corolla  Car_Name_corolla altis  \
# 0          False          False             False                   False
# 1          False          False             False                   False
# 2           True          False             False                   False
# 3          False          False             False                   False
# 4          False          False             False                   False
#
#    Car_Name_creta  Car_Name_dzire  Car_Name_elantra  Car_Name_eon  \
# 0           False           False             False         False
# 1           False           False             False         False
# 2           False           False             False         False
# 3           False           False             False         False
# 4           False           False             False         False
#
#    Car_Name_ertiga  Car_Name_etios cross  Car_Name_etios g  Car_Name_etios gd  \
# 0            False                 False             False              False
# 1            False                 False             False              False
# 2            False                 False             False              False
# 3            False                 False             False              False
# 4            False                 False             False              False
#
#    Car_Name_etios liva  Car_Name_fortuner  Car_Name_grand i10  Car_Name_i10  \
# 0                False              False               False         False
# 1                False              False               False         False
# 2                False              False               False         False
# 3                False              False               False         False
# 4                False              False               False         False
#
#    Car_Name_i20  Car_Name_ignis  Car_Name_innova  Car_Name_jazz  \
# 0         False           False            False          False
# 1         False           False            False          False
# 2         False           False            False          False
# 3         False           False            False          False
# 4         False           False            False          False
#
#    Car_Name_land cruiser  Car_Name_omni  Car_Name_ritz  Car_Name_s cross  \
# 0                  False          False           True             False
# 1                  False          False          False             False
# 2                  False          False          False             False
# 3                  False          False          False             False
# 4                  False          False          False             False
#
#    Car_Name_swift  Car_Name_sx4  Car_Name_verna  Car_Name_vitara brezza  \
# 0           False         False           False                   False
# 1           False          True           False                   False
# 2           False         False           False                   False
# 3           False         False           False                   False
# 4            True         False           False                   False
#
#    Car_Name_wagon r  Car_Name_xcent  Fuel_Type_CNG  Fuel_Type_Diesel  \
# 0             False           False          False             False
# 1             False           False          False              True
# 2             False           False          False             False
# 3              True           False          False             False
# 4             False           False          False              True
#
#    Fuel_Type_Petrol
# 0              True
# 1             False
# 2              True
# 3              True
# 4             False

# %%
df_main = pd.get_dummies(data = df_main,drop_first=True)

# %%
df_main.head()
# Out:
#    Selling_Price(lacs)  Present_Price(lacs)  Kms_Driven  Past_Owners  Age  \
# 0                 3.35                 5.59       27000            0    6
# 1                 4.75                 9.54       43000            0    7
# 2                 7.25                 9.85        6900            0    3
# 3                 2.85                 4.15        5200            0    9
# 4                 4.60                 6.87       42450            0    6
#
#    Car_Name_800  Car_Name_Activa 3g  Car_Name_Activa 4g  \
# 0         False               False               False
# 1         False               False               False
# 2         False               False               False
# 3         False               False               False
# 4         False               False               False
#
#    Car_Name_Bajaj  ct 100  Car_Name_Bajaj Avenger 150  \
# 0                   False                       False
# 1                   False                       False
# 2                   False                       False
# 3                   False                       False
# 4                   False                       False
#
#    Car_Name_Bajaj Avenger 150 street  Car_Name_Bajaj Avenger 220  \
# 0                              False                       False
# 1                              False                       False
# 2                              False                       False
# 3                              False                       False
# 4                              False                       False
#
#    Car_Name_Bajaj Avenger 220 dtsi  Car_Name_Bajaj Avenger Street 220  \
# 0                            False                              False
# 1                            False                              False
# 2                            False                              False
# 3                            False                              False
# 4                            False                              False
#
#    Car_Name_Bajaj Discover 100  Car_Name_Bajaj Discover 125  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    Car_Name_Bajaj Dominar 400  Car_Name_Bajaj Pulsar  NS 200  \
# 0                       False                          False
# 1                       False                          False
# 2                       False                          False
# 3                       False                          False
# 4                       False                          False
#
#    Car_Name_Bajaj Pulsar 135 LS  Car_Name_Bajaj Pulsar 150  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
#
#    Car_Name_Bajaj Pulsar 220 F  Car_Name_Bajaj Pulsar NS 200  \
# 0                        False                         False
# 1                        False                         False
# 2                        False                         False
# 3                        False                         False
# 4                        False                         False
#
#    Car_Name_Bajaj Pulsar RS200  Car_Name_Hero  CBZ Xtreme  \
# 0                        False                      False
# 1                        False                      False
# 2                        False                      False
# 3                        False                      False
# 4                        False                      False
#
#    Car_Name_Hero  Ignitor Disc  Car_Name_Hero Extreme  Car_Name_Hero Glamour  \
# 0                        False                  False                  False
# 1                        False                  False                  False
# 2                        False                  False                  False
# 3                        False                  False                  False
# 4                        False                  False                  False
#
#    Car_Name_Hero Honda CBZ extreme  Car_Name_Hero Honda Passion Pro  \
# 0                            False                            False
# 1                            False                            False
# 2                            False                            False
# 3                            False                            False
# 4                            False                            False
#
#    Car_Name_Hero Hunk  Car_Name_Hero Passion Pro  Car_Name_Hero Passion X pro  \
# 0               False                      False                        False
# 1               False                      False                        False
# 2               False                      False                        False
# 3               False                      False                        False
# 4               False                      False                        False
#
#    Car_Name_Hero Splender Plus  Car_Name_Hero Splender iSmart  \
# 0                        False                          False
# 1                        False                          False
# 2                        False                          False
# 3                        False                          False
# 4                        False                          False
#
#    Car_Name_Hero Super Splendor  Car_Name_Honda Activa 125  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
#
#    Car_Name_Honda Activa 4G  Car_Name_Honda CB Hornet 160R  \
# 0                     False                          False
# 1                     False                          False
# 2                     False                          False
# 3                     False                          False
# 4                     False                          False
#
#    Car_Name_Honda CB Shine  Car_Name_Honda CB Trigger  \
# 0                    False                      False
# 1                    False                      False
# 2                    False                      False
# 3                    False                      False
# 4                    False                      False
#
#    Car_Name_Honda CB Unicorn  Car_Name_Honda CB twister  \
# 0                      False                      False
# 1                      False                      False
# 2                      False                      False
# 3                      False                      False
# 4                      False                      False
#
#    Car_Name_Honda CBR 150  Car_Name_Honda Dream Yuga   Car_Name_Honda Karizma  \
# 0                   False                       False                   False
# 1                   False                       False                   False
# 2                   False                       False                   False
# 3                   False                       False                   False
# 4                   False                       False                   False
#
#    Car_Name_Hyosung GT250R  Car_Name_KTM 390 Duke   Car_Name_KTM RC200  \
# 0                    False                   False               False
# 1                    False                   False               False
# 2                    False                   False               False
# 3                    False                   False               False
# 4                    False                   False               False
#
#    Car_Name_KTM RC390  Car_Name_Mahindra Mojo XT300  \
# 0               False                         False
# 1               False                         False
# 2               False                         False
# 3               False                         False
# 4               False                         False
#
#    Car_Name_Royal Enfield Bullet 350  Car_Name_Royal Enfield Classic 350  \
# 0                              False                               False
# 1                              False                               False
# 2                              False                               False
# 3                              False                               False
# 4                              False                               False
#
#    Car_Name_Royal Enfield Classic 500  Car_Name_Royal Enfield Thunder 350  \
# 0                               False                               False
# 1                               False                               False
# 2                               False                               False
# 3                               False                               False
# 4                               False                               False
#
#    Car_Name_Royal Enfield Thunder 500  Car_Name_Suzuki Access 125  \
# 0                               False                       False
# 1                               False                       False
# 2                               False                       False
# 3                               False                       False
# 4                               False                       False
#
#    Car_Name_TVS Apache RTR 160  Car_Name_TVS Apache RTR 180  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    Car_Name_TVS Jupyter  Car_Name_TVS Sport   Car_Name_TVS Wego  \
# 0                 False                False              False
# 1                 False                False              False
# 2                 False                False              False
# 3                 False                False              False
# 4                 False                False              False
#
#    Car_Name_UM Renegade Mojave  Car_Name_Yamaha FZ  v 2.0  \
# 0                        False                      False
# 1                        False                      False
# 2                        False                      False
# 3                        False                      False
# 4                        False                      False
#
#    Car_Name_Yamaha FZ 16  Car_Name_Yamaha FZ S   Car_Name_Yamaha FZ S V 2.0  \
# 0                  False                  False                       False
# 1                  False                  False                       False
# 2                  False                  False                       False
# 3                  False                  False                       False
# 4                  False                  False                       False
#
#    Car_Name_Yamaha Fazer   Car_Name_alto 800  Car_Name_alto k10  \
# 0                   False              False              False
# 1                   False              False              False
# 2                   False              False              False
# 3                   False              False              False
# 4                   False              False              False
#
#    Car_Name_amaze  Car_Name_baleno  Car_Name_brio  Car_Name_camry  \
# 0           False            False          False           False
# 1           False            False          False           False
# 2           False            False          False           False
# 3           False            False          False           False
# 4           False            False          False           False
#
#    Car_Name_ciaz  Car_Name_city  Car_Name_corolla  Car_Name_corolla altis  \
# 0          False          False             False                   False
# 1          False          False             False                   False
# 2           True          False             False                   False
# 3          False          False             False                   False
# 4          False          False             False                   False
#
#    Car_Name_creta  Car_Name_dzire  Car_Name_elantra  Car_Name_eon  \
# 0           False           False             False         False
# 1           False           False             False         False
# 2           False           False             False         False
# 3           False           False             False         False
# 4           False           False             False         False
#
#    Car_Name_ertiga  Car_Name_etios cross  Car_Name_etios g  Car_Name_etios gd  \
# 0            False                 False             False              False
# 1            False                 False             False              False
# 2            False                 False             False              False
# 3            False                 False             False              False
# 4            False                 False             False              False
#
#    Car_Name_etios liva  Car_Name_fortuner  Car_Name_grand i10  Car_Name_i10  \
# 0                False              False               False         False
# 1                False              False               False         False
# 2                False              False               False         False
# 3                False              False               False         False
# 4                False              False               False         False
#
#    Car_Name_i20  Car_Name_ignis  Car_Name_innova  Car_Name_jazz  \
# 0         False           False            False          False
# 1         False           False            False          False
# 2         False           False            False          False
# 3         False           False            False          False
# 4         False           False            False          False
#
#    Car_Name_land cruiser  Car_Name_omni  Car_Name_ritz  Car_Name_s cross  \
# 0                  False          False           True             False
# 1                  False          False          False             False
# 2                  False          False          False             False
# 3                  False          False          False             False
# 4                  False          False          False             False
#
#    Car_Name_swift  Car_Name_sx4  Car_Name_verna  Car_Name_vitara brezza  \
# 0           False         False           False                   False
# 1           False          True           False                   False
# 2           False         False           False                   False
# 3           False         False           False                   False
# 4            True         False           False                   False
#
#    Car_Name_wagon r  Car_Name_xcent  Fuel_Type_CNG  Fuel_Type_Diesel  \
# 0             False           False          False             False
# 1             False           False          False              True
# 2             False           False          False             False
# 3              True           False          False             False
# 4             False           False          False              True
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0              True                   False                 True
# 1             False                   False                 True
# 2              True                   False                 True
# 3              True                   False                 True
# 4             False                   False                 True

# %% [markdown]
# Train-Test Split

# %%
# Separating target variable and its features
y = df_main['Selling_Price(lacs)']
X = df_main.drop('Selling_Price(lacs)',axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
print("x train: ",X_train.shape)
print("x test: ",X_test.shape)
print("y train: ",y_train.shape)
print("y test: ",y_test.shape)
# Out:
# x train:  (240, 107)
# x test:  (61, 107)
# y train:  (240,)
# y test:  (61,)

# %% [markdown]
# Model Creation/Evaluation

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

# %%
CV = []
R2_train = []
R2_test = []

def car_pred_model(model,model_name):
    # Training model
    model.fit(X_train,y_train)

    # R2 score of train set
    y_pred_train = model.predict(X_train)
    R2_train_model = r2_score(y_train,y_pred_train)
    R2_train.append(round(R2_train_model,2))

    # R2 score of test set
    y_pred_test = model.predict(X_test)
    R2_test_model = r2_score(y_test,y_pred_test)
    R2_test.append(round(R2_test_model,2))

    # R2 mean of train set using Cross validation
    cross_val = cross_val_score(model ,X_train ,y_train ,cv=5)
    cv_mean = cross_val.mean()
    CV.append(round(cv_mean,2))

    # Printing results
    print("Train R2-score :",round(R2_train_model,2))
    print("Test R2-score :",round(R2_test_model,2))
    print("Train CV scores :",cross_val)
    print("Train CV mean :",round(cv_mean,2))

    # Plotting Graphs
    # Residual Plot of train data
    fig, ax = plt.subplots(1,2,figsize = (10,4))
    ax[0].set_title('Residual Plot of Train samples')
    sns.distplot((y_train-y_pred_train),hist = False,ax = ax[0])
    ax[0].set_xlabel('y_train - y_pred_train')

    # Y_test vs Y_train scatter plot
    ax[1].set_title('y_test vs y_pred_test')
    ax[1].scatter(x = y_test, y = y_pred_test)
    ax[1].set_xlabel('y_test')
    ax[1].set_ylabel('y_pred_test')

    plt.show()

# %%
#Standard Linear Regression or Ordinary Least Squares
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
car_pred_model(lr,"Linear_regressor.pkl")
# Out:
# Train R2-score : 0.94
# Test R2-score : 0.81
# Train CV scores : [ 0.78162646  0.95905811  0.79678351 -0.12406314  0.63297791]
# Train CV mean : 0.61

# %%
#Ridge
from sklearn.linear_model import Ridge
from sklearn.model_selection import RandomizedSearchCV

# Creating Ridge model object
rg = Ridge()
# range of alpha
alpha = np.logspace(-3,3,num=14)

# Creating RandomizedSearchCV to find the best estimator of hyperparameter
rg_rs = RandomizedSearchCV(estimator = rg, param_distributions = dict(alpha=alpha))

car_pred_model(rg_rs,"ridge.pkl")
# Out:
# Train R2-score : 0.91
# Test R2-score : 0.89
# Train CV scores : [0.87988119 0.9264255  0.85008384 0.85168492 0.62982808]
# Train CV mean : 0.83

# %%
# Lasso
from sklearn.linear_model import Lasso
from sklearn.model_selection import RandomizedSearchCV

ls = Lasso()
alpha = np.logspace(-3,3,num=14) # range for alpha

ls_rs = RandomizedSearchCV(estimator = ls, param_distributions = dict(alpha=alpha))

# %%
car_pred_model(ls_rs,"lasso.pkl")
# Out:
# Train R2-score : 0.9
# Test R2-score : 0.9
# Train CV scores : [0.8576629  0.90737495 0.8613766  0.8586057  0.59519208]
# Train CV mean : 0.82

# %%
#Random Forest
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV

rf = RandomForestRegressor()

# Number of trees in Random forest
n_estimators=list(range(500,1000,100))
# Maximum number of levels in a tree
max_depth=list(range(4,9,4))
# Minimum number of samples required to split an internal node
min_samples_split=list(range(4,9,2))
# Minimum number of samples required to be at a leaf node.
min_samples_leaf=[1,2,5,7]
# Number of fearures to be considered at each split
max_features=['auto','sqrt']

# Hyperparameters dict
param_grid = {"n_estimators":n_estimators,
              "max_depth":max_depth,
              "min_samples_split":min_samples_split,
              "min_samples_leaf":min_samples_leaf,
              "max_features":max_features}

rf_rs = RandomizedSearchCV(estimator = rf, param_distributions = param_grid)

# %%
car_pred_model(rf_rs,'random_forest.pkl')
# Out:
# Train R2-score : 0.87
# Test R2-score : 0.92
# Train CV scores : [0.78084423 0.70699359 0.73633728 0.63129403 0.39672003]
# Train CV mean : 0.65

# %%
print(rf_rs.best_estimator_)
# Out:
# RandomForestRegressor(max_depth=8, max_features='sqrt', min_samples_split=6,
#                       n_estimators=500)

# %%
#Gradient Boosting
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import RandomizedSearchCV

gb = GradientBoostingRegressor()

# Rate at which correcting is being made
learning_rate = [0.001, 0.01, 0.1, 0.2]
# Number of trees in Gradient boosting
n_estimators=list(range(500,1000,100))
# Maximum number of levels in a tree
max_depth=list(range(4,9,4))
# Minimum number of samples required to split an internal node
min_samples_split=list(range(4,9,2))
# Minimum number of samples required to be at a leaf node.
min_samples_leaf=[1,2,5,7]
# Number of fearures to be considered at each split
max_features=['auto','sqrt']

# Hyperparameters dict
param_grid = {"learning_rate":learning_rate,
              "n_estimators":n_estimators,
              "max_depth":max_depth,
              "min_samples_split":min_samples_split,
              "min_samples_leaf":min_samples_leaf,
              "max_features":max_features}

gb_rs = RandomizedSearchCV(estimator = gb, param_distributions = param_grid)

# %%
car_pred_model(gb_rs,"gradient_boosting.pkl")
# Out:
# Train R2-score : 1.0
# Test R2-score : 0.97
# Train CV scores : [0.88744121 0.9179947  0.8745208  0.89116053 0.72787697]
# Train CV mean : 0.86

# %%
Technique = ["LinearRegression","Ridge","Lasso","RandomForestRegressor","GradientBoostingRegressor"]
results=pd.DataFrame({'Model': Technique,'R Squared(Train)': R2_train,'R Squared(Test)': R2_test,'CV score mean(Train)': CV})
display(results)
# Out:
#                        Model  R Squared(Train)  R Squared(Test)  \
# 0           LinearRegression              0.94             0.81
# 1                      Ridge              0.91             0.89
# 2                      Lasso              0.90             0.90
# 3      RandomForestRegressor              0.87             0.92
# 4  GradientBoostingRegressor              1.00             0.97
#
#    CV score mean(Train)
# 0                  0.61
# 1                  0.83
# 2                  0.82
# 3                  0.65
# 4                  0.86
